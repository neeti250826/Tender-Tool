# %% [markdown]
# # Singapore GeBIZ (SG_GEBIZ) - Colab Scaffold
#
# This notebook runs the SG_GEBIZ scaffold scraper end-to-end (placeholder output).

# %%
# Install dependencies
# !pip -q install -r "requirements.txt"

# (Optional) Mount Google Drive
#from google.colab import drive
#drive.mount('/content/drive')
# Out:
# [notice] A new release of pip is available: 25.1.1 -> 26.0.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
# @title Notebook location
# Set this to the folder that contains gebiz_scraper.py and requirements.txt.
TOOL_DIR = '.'  # @param {type:'string'}
import os
os.chdir(TOOL_DIR)
# !ls -la
# Out:
# 'ls' is not recognized as an internal or external command,
# operable program or batch file.

# %%
# @title Config
DATE_FROM = '2026-01-01'  # @param {type:'string'}
DATE_TO = '2026-01-31'    # @param {type:'string'}
QUERY = 'ivd'            # @param {type:'string'}
OUTPUT_TARGET = '/content/drive/MyDrive/Tender Outputs'  # @param {type:'string'}
PROJECT_NAME = 'MDT_2026' # @param {type:'string'}
WEBSITE_ID = 'SG_GEBIZ'   # @param {type:'string'}
SOURCE_LABEL = 'Singapore GeBIZ'  # @param {type:'string'}
REGION = 'EMEA'           # @param {type:'string'}

# %%
# Run scaffold scraper
# !python "gebiz_scraper.py" \
  --date-from "{DATE_FROM}" \
  --date-to "{DATE_TO}" \
  --query "{QUERY}" \
  --output-target "{OUTPUT_TARGET}" \
  --project-name "{PROJECT_NAME}" \
  --website-id "{WEBSITE_ID}" \
  --source-label "{SOURCE_LABEL}" \
  --region "{REGION}"
# Out:
# C:\Users\Neeti\PycharmProjects\Clearstate\.venv\Lib\site-packages\requests\__init__.py:113: RequestsDependencyWarning: urllib3 (2.6.3) or chardet (7.0.1)/charset_normalizer (3.4.5) doesn't match a supported version!
#   warnings.warn(
# Traceback (most recent call last):
#   File "C:\Users\Neeti\PycharmProjects\Clearstate\gebiz_scraper.py", line 44, in <module>
#     mdt_export = importlib.import_module("mdt_export")
#                  ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "C:\Users\Neeti\AppData\Local\Programs\Python\Python311\Lib\importlib\__init__.py", line 126, in import_module
#     return _bootstrap._gcd_import(name[level:], package, level)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "<frozen importlib._bootstrap>", line 1204, in _gcd_import
#   File "<frozen importlib._bootstrap>", line 1176, in _find_and_load
#   File "<frozen importlib._bootstrap>", line 1140, in _find_and_load_unlocked
# ...
